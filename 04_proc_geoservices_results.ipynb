# %%
import pandas as pd
import glob
import os

# %%
#path = './data/geoservices_results' # use your path
all_files = glob.glob("data/geoservices_results/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.drop_duplicates()
# Out:
#                                   Hinweis zu den Daten  \
# 0    Für die Richtigkeit, Aktualität und Vollständi...
# 1    Für die Richtigkeit, Aktualität und Vollständi...
# 2    Für die Richtigkeit, Aktualität und Vollständi...
# 3    Für die Richtigkeit, Aktualität und Vollständi...
# 4    Für die Richtigkeit, Aktualität und Vollständi...
# ..                                                 ...
# 487  Für die Richtigkeit, Aktualität und Vollständi...
# 488  Für die Richtigkeit, Aktualität und Vollständi...
# 489  Für die Richtigkeit, Aktualität und Vollständi...
# 490  Für die Richtigkeit, Aktualität und Vollständi...
# 491  Für die Richtigkeit, Aktualität und Vollständi...
#
#                         Name                 Nummer  \
# 0             Obernburg Nord                027_000
# 1        Am oberen neuen Weg                006_000
# 2                Volksschule                038_000
# 3     Am Graben - Brennerweg                002_000
# 4                   Rüdhölle                031_000
# ..                       ...                    ...
# 487   Säumerweg (Änderung 2)  09275-156-006_000-0_2
# 488  Ebenäcker (Änderung 19)    09275-156-001_019-0
# 489  Ebenäcker (Änderung 25)    09275-156-001_025-0
# 490  Ebenäcker (Änderung 23)    09275-156-001_023-0
# 491  Ebenäcker (Änderung 26)    09275-156-001_026-0
#
#                            Beschreibung  Gemeindekennzeichen  \
# 0                        Obernburg Nord              9676145
# 1                   Am oberen neuen Weg              9676145
# 2                           Volksschule              9676145
# 3                Am Graben - Brennerweg              9676145
# 4                              Rüdhölle              9676145
# ..                                  ...                  ...
# 487   2. Änderung zu Urplan "Säumerweg"              9275156
# 488  28. Änderung zu Urplan "Ebenäcker"              9275156
# 489  25. Änderung zu Urplan "Ebenäcker"              9275156
# 490  23. Änderung zu Urplan "Ebenäcker"              9275156
# 491  26. Änderung zu Urplan "Ebenäcker"              9275156
#
#        Stadt/Gemeinde                                Planart  \
# 0    Obernburg a.Main           qualifizierter Bebauungsplan
# 1    Obernburg a.Main           qualifizierter Bebauungsplan
# 2    Obernburg a.Main           qualifizierter Bebauungsplan
# 3    Obernburg a.Main           qualifizierter Bebauungsplan
# 4    Obernburg a.Main           qualifizierter Bebauungsplan
# ..                ...                                    ...
# 487         Wegscheid           qualifizierter Bebauungsplan
# 488         Wegscheid           qualifizierter Bebauungsplan
# 489         Wegscheid           qualifizierter Bebauungsplan
# 490         Wegscheid  BPlan Innenentwicklung (§§ 13a BauGB)
# 491         Wegscheid  BPlan Innenentwicklung (§§ 13a BauGB)
#
#     Datum des Inkrafttretens Rechtsstand(vorbehaltlich aktueller Änderungen)  \
# 0                 1963-04-18                                     Rechtskraft
# 1                 1963-10-11                                     Rechtskraft
# 2                 1971-09-06                                     Rechtskraft
# 3                 1980-07-01                                     Rechtskraft
# 4                 1980-07-01                                     Rechtskraft
# ..                       ...                                             ...
# 487               2019-03-19                                     Rechtskraft
# 488               2022-11-10                                     Rechtskraft
# 489               2023-02-14                                     Rechtskraft
# 490               2023-03-13                                     Rechtskraft
# 491               2023-05-31                                     Rechtskraft
#
#                                   URL des Rasterbildes  \
# 0    http://gis.kreis-mil.de/bpl/Obernburg/Obernbur...
# 1    http://gis.kreis-mil.de/bpl/Obernburg/Am_Obere...
# 2    http://gis.kreis-mil.de/bpl/Obernburg/Volkssch...
# 3    http://gis.kreis-mil.de/bpl/Obernburg/Am_Grabe...
# 4    http://gis.kreis-mil.de/bpl/Obernburg/Ruedhoel...
# ..                                                 ...
# 487  https://www.landkreis-passau.de/internet-links...
# 488  https://www.landkreis-passau.de/internet-links...
# 489  https://www.landkreis-passau.de/internet-links...
# 490  https://www.landkreis-passau.de/internet-links...
# 491  https://www.landkreis-passau.de/internet-links...
#
#                                        URL zur Legende  \
# 0    http://gis.kreis-mil.de/bpl/Obernburg/Obernbur...
# 1    http://gis.kreis-mil.de/bpl/Obernburg/Am_Obere...
# 2    http://gis.kreis-mil.de/bpl/Obernburg/Volkssch...
# 3    http://gis.kreis-mil.de/bpl/Obernburg/Am_Grabe...
# 4    http://gis.kreis-mil.de/bpl/Obernburg/Ruedhoel...
# ..                                                 ...
# 487  https://www.landkreis-passau.de/internet-links...
# 488  https://www.landkreis-passau.de/internet-links...
# 489  https://www.landkreis-passau.de/internet-links...
# 490  https://www.landkreis-passau.de/internet-links...
# 491  https://www.landkreis-passau.de/internet-links...
#
#                         URL der textlichen Festsetzung
# 0    http://gis.kreis-mil.de/bpl/Obernburg/Obernbur...
# 1    http://gis.kreis-mil.de/bpl/Obernburg/Am_Obere...
# 2    http://gis.kreis-mil.de/bpl/Obernburg/Volkssch...
# 3    http://gis.kreis-mil.de/bpl/Obernburg/Am_Grabe...
# 4    http://gis.kreis-mil.de/bpl/Obernburg/Ruedhoel...
# ..                                                 ...
# 487  https://www.landkreis-passau.de/internet-links...
# 488  https://www.landkreis-passau.de/internet-links...
# 489  https://www.landkreis-passau.de/internet-links...
# 490  https://www.landkreis-passau.de/internet-links...
# 491  https://www.landkreis-passau.de/internet-links...
#
# [484 rows x 12 columns]
